# %%
# !pip install webdriver-manager
# !pip install selenium==4.9.1
# !pip install BeautifulSoup4

# %%
from bs4 import BeautifulSoup 
from selenium import webdriver
from selenium.webdriver.chrome.service import Service as ChromeService
from webdrivermanager.chrome import ChromeDriverManager
from webdriver_manager.chrome import ChromeDriverManager

chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument("--headless")

driver = webdriver.Chrome(service=ChromeService(ChromeDriverManager().install()))

#Query to obtain links
query = 'Joko Widodo'       # term yang akan disearch

#links = [] # Initiate empty list to capture final results
#Specify number of pages on google search, each page contains 10 links
n_pages = 10                # jumlah page

for page in range(1, n_pages):
    url = "http://www.google.com/search?q=" + query + "&start=" + str((page - 1) * 10) 
    driver.get(url)
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    # soup = BeautifulSoup (r.text, 'html.parser')

    search = soup.find_all('div', class_ = "yuRUbf")        # merujuk pada 'div class' milik halaman google search
    for h in search:
        #links.append(h.a.get('href'))
        print(h.a.text)                 # title
        print(h.a.get('href'))          # url

driver.quit()
# Out:
# Presiden Joko WidodoPresiden RIhttps://www.presidenri.go.id › presiden-joko-widodo
# https://www.presidenri.go.id/presiden-joko-widodo/
# Joko Widodo - Wikipedia bahasa Indonesia, ensiklopedia ...Wikipediahttps://id.wikipedia.org › wiki › Joko_Widodo
# https://id.wikipedia.org/wiki/Joko_Widodo
# Joko Widodo (@jokowi) • Instagram photos and videosInstagramhttps://www.instagram.com › ...
# https://www.instagram.com/jokowi/
# Joko Widodo - Wikipedia bahasa Indonesia, ensiklopedia bebasWikipediahttps://id.wikipedia.org › wiki › Joko_Widodo
# https://id.wikipedia.org/wiki/Joko_Widodo#:~:text=Pendidikannya%20diawali%20dengan%20masuk%20SD,untuk%20kalangan%20menengah%20ke%20bawah.
# Kepemimpinan Indonesia dari Masa ke Masaumj.ac.idhttps://umj.ac.id › opini › kepemimpinan-indonesia-dari-...
# https://umj.ac.id/opini/kepemimpinan-indonesia-dari-masa-ke-masa/#:~:text=Kepemimpinan%20presiden%20Joko%20Widodo,pada%20tanggal%2021%20Juni%201961.
# ...
